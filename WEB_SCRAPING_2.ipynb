    r'Reviewed in India on (?P<date>.*?)\n'  # Date
    r'(?:Style Name:.*?\n)?'  # Optional style line
    r'(?:Verified Purchase\n)?'  # Optional Verified Purchase line
    r'(?P<review>.*?)(?:\nHelpful|\nReport|\Z)',  # Review ends before Helpful/Report/end
    re.DOTALL | re.MULTILINE
)

# Find matches
matches = pattern.finditer(text)

# Extract data to a list of dictionaries
data = [match.groupdict() for match in matches]

# Convert to DataFrame
df5 = pd.DataFrame(data)
# Clean unwanted prefix from the 'review' column
df5['review'] = df5['review'].str.replace(
    r'^Pattern Name:.*?Verified Purchase\n?', '',
    regex=True
)

# Display result
df5
# Out:
#                                                 name rating             title  \
# 0  Shortcuts menu\nSkip to\nMain content\nKeyboar...    4.0    Good product 👌
# 1                                     \nReport\n\njk    5.0   value for money
# 2                                \nReport\n\nUnknown    2.0      Disappointed
# 3                        \nReport\n\nAmazon Customer    5.0  Awesome because;
# 4                                  \nReport\n\nkumar    1.0     Chinese brand
#
#                 date                                             review
# 0    7 November 2022              Overall nice product, value for money
# 1    31 October 2022  very nice product and very comfortable for the...
# 2  13 September 2020  Pattern Name: TapeSize: New Born- Feet\nThe ma...
# 3   25 November 2019  Pattern Name: TapeSize: New Born- Feet\nThis d...
# 4    9 November 2019  Pattern Name: TapeSize: New Born- Feet\nComple...

# %%
combined_df = pd.concat([df1,df2,df3,df4,df5], ignore_index=True)

# %%
combined_df
# Out:
#                                                  name rating  \
# 0   Shortcuts menu\nSkip to\nMain content\nKeyboar...    1.0
# 1                                   \nReport\n\nPearl    4.0
# 2                                    \nReport\n\nPree    5.0
# 3                                   \nReport\n\nDivya    3.0
# 4                               \nReport\n\nSwati Rao    1.0
# 5                             \nReport\n\nParth Barad    5.0
# 6                                 \nReport\n\nArsheez    2.0
# 7                                 \nReport\n\nDeepika    5.0
# 8                           \nReport\n\nPradeep Rathi    5.0
# 9                                   \nReport\n\nDev B    3.0
# 10  Shortcuts menu\nSkip to\nMain content\nKeyboar...    1.0
# 11                         \nReport\n\nAlisha sakhuja    1.0
# 12                           \nReport\n\nUpasna gupta    5.0
# 13                                \nReport\n\nShivani    5.0
# ...

# %%
combined_df['name'] = combined_df['name'].astype(str).str.replace('\n', '***', regex=False)

# %%
combined_df['name'] = combined_df['name'].astype(str).str.split(r'\*{3}').str[-1]

# %%
combined_df
# Out:
#                 name rating  \
# 0       vipin chawla    1.0
# 1              Pearl    4.0
# 2               Pree    5.0
# 3              Divya    3.0
# 4          Swati Rao    1.0
# 5        Parth Barad    5.0
# 6            Arsheez    2.0
# 7            Deepika    5.0
# 8      Pradeep Rathi    5.0
# 9              Dev B    3.0
# 10     Alind Dwivedi    1.0
# 11    Alisha sakhuja    1.0
# 12      Upasna gupta    5.0
# 13           Shivani    5.0
# 14     Nishant tyagi    5.0
# 15             Parul    5.0
# 16         Simran S.    3.0
# 17  Prisila Netalkar    2.0
# 18           kirtika    5.0
# 19             Swati    5.0
# 20    Yudhveer Patil    5.0
# 21          Shreya g    5.0
# 22              Luis    1.0
# 23             Subbu    1.0
# 24         Madhuri G    1.0
# 25    Seldon koireng    5.0
# 26            Raksha    4.0
# 27      amithash m p    1.0
# 28             Praky    1.0
# 29    Harinder Singh    5.0
# 30      Aarav Tanwar    5.0
# 31    Ayush Aggarwal    5.0
# ...

# %%
combined_df.to_csv('diaper14.csv', index=False)
